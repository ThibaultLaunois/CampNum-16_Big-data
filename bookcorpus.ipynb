# %% [markdown]
# # Import Module

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
# import pyspark.sql.functions as sf
# import pyspark
# import numpy as np

# %%
sc = SparkContext("local", "test")
spark = SparkSession.builder.appName("test").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/18 08:28:31 WARN Utils: Your hostname, promo-ds4-gra9-1, resolves to a loopback address: 127.0.1.1; using 51.91.85.73 instead (on interface ens3)
# 25/11/18 08:28:31 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/18 08:28:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Load Data

# %%
textFile = sc.textFile("books_large/books_large_p1.txt,books_large/books_large_p2.txt")

# %%
textFile.first()
# Out:
# 'the half-ling book one in the fall of igneeria series kaylee soderburg copyright 2013 kaylee soderburg all rights reserved .'

# %% [markdown]
# # Most Words

# %%
wordCounts = textFile.flatMap(lambda x: x.lower().split()).map(lambda x: x.strip('“".?!:,;.-:\'')).countByValue()

# %%
wordCounts = sorted(
        wordCounts.items(),
        key=lambda x:x[1],
        reverse=True
    )

# %%
textFile.getNumPartitions()
# Out:
# 138

# %%
textFile.count()
# Out:
# 74004228

# %%
forbidden_words = ["", '``', "''", "n't", "'s", "'m", "'d", "!", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
for word in wordCounts[:200]:
    if word[0] not in forbidden_words:
        print(word)
# Out:
# ('said', 3396929)
# ('could', 2708098)
# ('would', 2675259)
# ('back', 2574524)
# ('like', 2548998)
# ('one', 2476924)
# ('know', 1942831)
# ('time', 1606261)
# ('eyes', 1577282)
# ('get', 1522800)
# ('around', 1286171)
# ('even', 1250055)
# ('way', 1248552)
# ('going', 1247045)
# ('see', 1241349)
# ('head', 1238661)
# ('right', 1174601)
# ('want', 1160114)
# ("'re", 1152621)
# ('looked', 1127717)
# ('think', 1113969)
# ('go', 1113283)
# ('hand', 1110693)
# ('away', 1057959)
# ("'", 1053707)
# ('still', 1033252)
# ('something', 1025859)
# ('face', 1007769)
# ('us', 1006837)
# ('never', 962296)
# ('asked', 944124)
# ("'ll", 942022)
# ('thought', 931338)
# ('man', 907300)
# ('good', 889637)
# ('look', 885281)
# ('made', 877958)
# ('well', 876450)
# ('much', 874997)
# ('two', 874867)
# ('knew', 851504)
# ('got', 838695)
# ('let', 836545)
# ('little', 834834)
# ('door', 828399)
# ('come', 795554)
# ('room', 791341)
# ('take', 788498)
# ('make', 786762)
# ('say', 755427)
# ('first', 747423)
# ('long', 745846)
# ('felt', 738511)
# ("'ve", 729733)
# ('took', 720062)
# ('wanted', 719991)
# ('turned', 709939)
# ('need', 705845)
# ('tell', 689177)
# ('hands', 688591)
# ('really', 685976)
# ('sure', 682891)
# ('voice', 648603)
# ('left', 621568)
# ('told', 620273)
# ('came', 619862)
# ('another', 618067)
# ('people', 616950)
# ('last', 595789)
# ('life', 585268)
# ('anything', 584190)
# ('body', 580381)
# ('behind', 568138)
# ('night', 567566)
# ('nothing', 566118)
# ('enough', 562316)
# ('went', 559998)
# ('feel', 557776)
# ('thing', 548730)
# ('side', 547698)
# ('might', 536442)
# ('day', 533904)
# ('saw', 530103)
# ('things', 522704)
# ('though', 518085)
# ('yes', 514999)
# ('maybe', 513722)
# ('put', 511092)
# ('find', 509123)
# ('every', 502456)
# ('ever', 497545)
# ('hair', 486042)
# ('moment', 483011)
# ('always', 476390)
# ('love', 474848)
# ('next', 473593)
